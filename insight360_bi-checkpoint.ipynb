# %%
import pandas as pd

df = pd.read_csv("clean_sales_data_export.csv")

df.head()
# Out:
#   order_id product_id  quantity  unit_price  net_revenue customer_id  \
# 0   539255     85099B        10        1.95        19.50       16316
# 1   539255      22422        12        0.65         7.80       16316
# 2   539255      21832        12        1.65        19.80       16316
# 3   539256      21754         6        5.95        35.70       15601
# 4   539256      21755         3        5.95        17.85       15601
#
#   customer_type   cost  profit          region  order_date price_valid_flag
# 0    Registered  12.68    6.83  United Kingdom  2010-12-16            VALID
# 1    Registered   5.07    2.73  United Kingdom  2010-12-16            VALID
# 2    Registered  12.87    6.93  United Kingdom  2010-12-16            VALID
# 3    Registered  23.21   12.50  United Kingdom  2010-12-16            VALID
# 4    Registered  11.60    6.25  United Kingdom  2010-12-16            VALID

# %%
df.shape
df.info()
df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   order_id          541909 non-null  str
#  1   product_id        541909 non-null  str
#  2   quantity          541909 non-null  int64
#  3   unit_price        541909 non-null  float64
#  4   net_revenue       541909 non-null  float64
#  5   customer_id       541909 non-null  str
#  6   customer_type     541909 non-null  str
#  7   cost              541909 non-null  float64
#  8   profit            541909 non-null  float64
#  9   region            541909 non-null  str
#  10  order_date        541909 non-null  str
#  11  price_valid_flag  541909 non-null  str
# dtypes: float64(4), int64(1), str(7)
# memory usage: 49.6 MB
#             quantity     unit_price    net_revenue           cost  \
# count  541909.000000  541909.000000  541909.000000  541909.000000
# ...

# %%
df['net_revenue'].describe()
# Out:
# count    541909.000000
# mean         17.987795
# std         378.810824
# min     -168469.600000
# 25%           3.400000
# 50%           9.750000
# 75%          17.400000
# max      168469.600000
# Name: net_revenue, dtype: float64

# %%
df['net_revenue'].hist(bins=50)
# Out:
# <Axes: >

# %%
customer_revenue = (
    df.groupby('customer_id')['net_revenue']
      .sum()
      .sort_values(ascending=False)
)

# %%
customer_revenue.head(10)
# Out:
# customer_id
# GUEST    1447682.12
# 14646     279489.02
# 18102     256438.49
# 17450     187482.17
# 14911     132572.62
# 12415     123725.45
# 14156     113384.14
# 17511      88125.38
# 16684      65892.08
# 13694      62653.10
# Name: net_revenue, dtype: float64

# %%
total_records = len(df)

defects = df[
    (df['unit_price'] <= 0) | (df['quantity'] <= 0)
]

defect_rate = len(defects) / total_records

defect_rate
# Out:
# 0.021791481595618452

# %%
defects['region'].value_counts()
# Out:
# region
# United Kingdom        10359
# Germany                 455
# Eire                    306
# France                  150
# Usa                     112
# Australia                77
# Spain                    49
# Italy                    45
# Belgium                  38
# Japan                    37
# Switzerland              36
# Portugal                 18
# Norway                   15
# Malta                    15
# Netherlands              12
# Sweden                   11
# Poland                   11
# Channel Islands          10
# Finland                  10
# Denmark                   9
# Cyprus                    8
# Singapore                 7
# Czech Republic            5
# Hong Kong                 4
# Austria                   3
# Israel                    2
# Bahrain                   1
# Saudi Arabia              1
# European Community        1
# Greece                    1
# Rsa                       1
# Name: count, dtype: int64

# %%
defects['customer_type'].value_counts()
# Out:
# customer_type
# Registered    8949
# Guest         2860
# Name: count, dtype: int64
